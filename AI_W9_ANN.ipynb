# %% [markdown]
# <a href="https://colab.research.google.com/github/anhhahuynh/Excercise-AI/blob/main/AI_W9_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
X=test_images
Y=test_labels

# %%
digit=train_images[20000]
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()
print('So nay la:',train_labels[15000])
# Out:
# So nay la: 5

# %%
for i in range (25):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i],cmap='gray',interpolation='none')
  plt.title('Số:{}'.format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(512,activation='relu',input_shape=(784,)))
model.add(Dense(10,activation='softmax')) 
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7fdc46c35ca0>>

# %%
train_images=train_images.reshape(60000,28*28)
train_images=train_images.astype('float32')/255
test_images=test_images.reshape(10000,28*28)
test_images=test_images.astype('float32')/255
from keras.utils import to_categorical
train_labels=to_categorical(train_labels,10)
test_labels=to_categorical(test_labels,10)
test_labels.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('Mất mát:',test_loss)
print('Độ chính xác:',test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0073 - accuracy: 0.9983
# Epoch 2/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0049 - accuracy: 0.9991
# Epoch 3/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0036 - accuracy: 0.9994
# Epoch 4/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0026 - accuracy: 0.9996
# Epoch 5/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 6/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 7/10
# 469/469 [==============================] - 5s 10ms/step - loss: 6.8010e-04 - accuracy: 1.0000
# Epoch 8/10
# 469/469 [==============================] - 6s 13ms/step - loss: 6.2151e-04 - accuracy: 1.0000
# Epoch 9/10
# 469/469 [==============================] - 5s 10ms/step - loss: 4.3802e-04 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
X[100]
img=X[1000]
plt.imshow(img)
plt.show()
print(Y[1000])
# Out:
# 9

# %%
import numpy as np
X_pred=X[10].reshape(1,28*28)
X_pred=X_pred.astype('float32')/255
np.argmax(model.predict(X_pred),axis=-1)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([0])
